# %% [markdown]
# # 03_TFTenricher
#
# try TFTenricher --> find relevant biological annotations to genes that are associated to a group of transcription factors (TFs)

# %%
import warnings
warnings.filterwarnings('ignore')

import itertools
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sys

from itertools import combinations 
from scipy.stats import boxcox
from scipy.stats import linregress
from scipy.stats import spearmanr
from scipy.stats import pearsonr
from statsmodels.stats.anova import anova_lm

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# import utils
sys.path.append("../../utils")
from plotting_utils import *
from classify_utils import *

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
mpl.rcParams['figure.autolayout'] = False

# %%
# import TFTenricher
from TFTenricher import TFTenricher

# %% [markdown]
# ### which TF?

# %%
TFs = ['GLIS1', 'TP73', 'ZNF180','ZNF506','ZNF529','ZNF740','ZNF85','ZSCAN22']
enr = TFTenricher.TFTenricher(TFs)
# Out:
# loading corr
# Done
# 0.0% of TFs are not found
# 0.504% of correlation table TFs were in the TF list

# %%
#We can view the putative target genes in the 'target_genes' attribute

print(enr.target_genes[:5])
print('Number of target genes: ', len(enr.target_genes))
# Out:
# ['AAMDC' 'ABCA9' 'ABCB5' 'ABCC1' 'ABCC9']
# Number of target genes:  1221

# %% [markdown]
# Next, we can map these target genes to annotated gene sets, such as GO, KEGG, Reactome, the GWAS catalogue, or any set provided by the user. The default is GO. As per default, TFTenricher also performs a Benjamini-Hochberg multiple testing correction, but this can be omitted, or the user can provide a custom function.

# %%
enr.downstream_enrich()
enr.enrichments
# Out:
#                                                            OR             p  \
# regulation of transcription, DNA-templated           2.392990  3.767522e-13
# cellular response to interleukin-7                  14.736626  4.415144e-05
# mRNA splicing, via spliceosome                       2.053883  5.316293e-04
# clathrin-dependent endocytosis                       6.069290  5.600700e-04
# IRE1-mediated unfolded protein response              3.609293  7.125033e-04
# ...                                                       ...           ...
# negative regulation of ryanodine-sensitive calc...   0.000000  1.000000e+00
# cAMP-mediated signaling                              0.000000  1.000000e+00
# regulation of release of sequestered calcium io...   0.000000  1.000000e+00
# killing by host of symbiont cells                    0.000000  1.000000e+00
# peptidyl-lysine monomethylation                      0.000000  1.000000e+00
#
#                                                       FDR
# regulation of transcription, DNA-templated           True
# cellular response to interleukin-7                  False
# mRNA splicing, via spliceosome                      False
# clathrin-dependent endocytosis                      False
# IRE1-mediated unfolded protein response             False
# ...                                                   ...
# negative regulation of ryanodine-sensitive calc...  False
# cAMP-mediated signaling                             False
# regulation of release of sequestered calcium io...  False
# killing by host of symbiont cells                   False
# peptidyl-lysine monomethylation                     False
#
# [2910 rows x 3 columns]

# %%
### plot 
f, ax = enr.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3785f0a9cb6a> in <module>
#       1 ### plot
# ----> 2 f, ax = enr.plot()
#
# ~/miniconda3/lib/python3.9/site-packages/TFTenricher/TFTenricher.py in plot(self, savename, plot_Ntop, textlength, sorton, remove_non_FDR, padding, tick_font_size)
#     198             plot_Ntop = self.enrichments.shape[0]
#     199
# --> 200         f, ax = plot_utils.plot_res(self.enrichments.copy(),
#     201                                     savename,
#     202                                     plot_Ntop,
#
# ~/miniconda3/lib/python3.9/site-packages/src/plot_utils.py in plot_res(enrichments, savename, plot_Ntop, color, textlength, cmap, sorton, remove_non_FDR, padding, tick_font_size)
#      93         ax.barh(padding*(nplot - i), width=enrichments.OR[i], height=0.4, color=cmap(norm(enrichments.p[i])))
#      94
# ---> 95     ax.set_xlim([0, enrichments.OR[:i].max()*1.2])
#      96     ax.set_yticks(padding*np.array(range(1, 1 + nplot)))
#      97     ax.set_yticklabels(enrichments.index[:plot_Ntop][::-1])
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3521         self._process_unit_info([("x", (left, right))], convert=False)
#    3522         left = self._validate_converted_limits(left, self.convert_xunits)
# -> 3523         right = self._validate_converted_limits(right, self.convert_xunits)
#    3524
#    3525         if left is None or right is None:
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3437             if (isinstance(converted_limit, Real)
#    3438                     and not np.isfinite(converted_limit)):
# -> 3439                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3440             return converted_limit
#    3441
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
### sort by pval 
f, ax = enr.plot( sorton='p')

# %% [markdown]
# The TFTenricher function also has several other databases to compare against, which is set by the 'db' option in the downstream_enrich method. The parameter 'db' can have the values 'REACTOME', 'KEGG', 'GWAS', 'GO', or be a dictionary set by the user.

# %%
enr.downstream_enrich(db='KEGG')
enr.enrichments
# Out:
#                                                           OR         p    FDR
# KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GLOBO_SERIES    1.637798  0.289677  False
# KEGG_N_GLYCAN_BIOSYNTHESIS                          0.994648  0.565032  False
# KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_KERATAN_SUL...  1.022373  0.588930  False
# KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_LACTO_AND_N...  0.742661  0.781072  False
# KEGG_GALACTOSE_METABOLISM                           0.742661  0.781072  False
# ...                                                      ...       ...    ...
# KEGG_BASE_EXCISION_REPAIR                           0.000000  1.000000  False
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_BIOSYNTHESIS     0.000000  1.000000  False
# KEGG_RIBOFLAVIN_METABOLISM                          0.000000  1.000000  False
# KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS              0.000000  1.000000  False
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                0.000000  1.000000  False
#
# [186 rows x 3 columns]

# %%
### plot 
f, ax = enr.plot(plot_Ntop=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f4cf4df29ad2> in <module>
#       1 ### plot
# ----> 2 f, ax = enr.plot(plot_Ntop=1)
#
# ~/miniconda3/lib/python3.9/site-packages/TFTenricher/TFTenricher.py in plot(self, savename, plot_Ntop, textlength, sorton, remove_non_FDR, padding, tick_font_size)
#     198             plot_Ntop = self.enrichments.shape[0]
#     199
# --> 200         f, ax = plot_utils.plot_res(self.enrichments.copy(),
#     201                                     savename,
#     202                                     plot_Ntop,
#
# ~/miniconda3/lib/python3.9/site-packages/src/plot_utils.py in plot_res(enrichments, savename, plot_Ntop, color, textlength, cmap, sorton, remove_non_FDR, padding, tick_font_size)
#      93         ax.barh(padding*(nplot - i), width=enrichments.OR[i], height=0.4, color=cmap(norm(enrichments.p[i])))
#      94
# ---> 95     ax.set_xlim([0, enrichments.OR[:i].max()*1.2])
#      96     ax.set_yticks(padding*np.array(range(1, 1 + nplot)))
#      97     ax.set_yticklabels(enrichments.index[:plot_Ntop][::-1])
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3521         self._process_unit_info([("x", (left, right))], convert=False)
#    3522         left = self._validate_converted_limits(left, self.convert_xunits)
# -> 3523         right = self._validate_converted_limits(right, self.convert_xunits)
#    3524
#    3525         if left is None or right is None:
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3437             if (isinstance(converted_limit, Real)
#    3438                     and not np.isfinite(converted_limit)):
# -> 3439                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3440             return converted_limit
#    3441
#
# ValueError: Axis limits cannot be NaN or Inf
